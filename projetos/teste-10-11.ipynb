# %%
nome_de_usuario = "Renata"
a = int(input('digite o primeiro numero de a'))
b = int(input('digite o segundo numero de b'))
c = int(input('digite o terceiro numero de c'))

soma = a + b
quadrado_c = c ** 2

if soma > quadrado_c:

    lista_valores=[a,b,c]
    print("a soma de a e b é maior que o c.")
    print("Valores de a, b e c:")
else:
    print("A soma de A e B não é maior que o c.")

if soma == (c):
    print("Bingo")
else:
    print("A soma de a e b não é igual a c.")


if soma < quadrado_c:
    print(f'o usuario {nome_de_usuario} digitou {a}, {b}, e {c}.  A "soma" é {soma} e c é {quadrado_c}')

else:
  print("a soma de a e b não é menor que c " )
# Out:
# digite o primeiro numero de a44
# digite o segundo numero de b 12
# digite o terceiro numero de c144
# A soma de A e B não é maior que o c.
# A soma de a e b não é igual a c.
# o usuario Renata digitou 44, 12, e 144.  A "soma" é 56 e c é 20736

# %%
a = input("digite a primeira palavra: " )
b = input("digite a segunda palavra: " )
c = input("digite a terceira palavra: " )
d = input("digite a quarta palavra: " )
e = input("digite a quinta palavra: " )
palavras = (a, b, c, d, e)
palavras_ordenadas = sorted(palavras)

for posicao, palavra in enumerate(palavras_ordenadas):
    print(f"Na posição {posicao}, o valor é {palavra}")
# Out:
# digite a primeira palavra: lua
# digite a segunda palavra: sol
# digite a terceira palavra: estrela
# digite a quarta palavra: universo
# digite a quinta palavra: planeta
# Na posição 0, o valor é estrela
# Na posição 1, o valor é lua
# Na posição 2, o valor é planeta
# Na posição 3, o valor é sol
# Na posição 4, o valor é universo
